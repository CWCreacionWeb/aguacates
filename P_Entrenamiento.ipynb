# %%
import P_Aguacate as P
P.Inicio(pMostrarEnunciado=False)
# Out:
# /home/jbentezag/.local/lib/python3.8/site-packages/xgboost/core.py:265: FutureWarning: Your system has an old version of glibc (< 2.28). We will stop supporting Linux distros with glibc older than 2.28 after **May 31, 2025**. Please upgrade to a recent Linux distro (with glibc 2.28+) to use future versions of XGBoost.
# Note: You have installed the 'manylinux2014' variant of XGBoost. Certain features such as GPU algorithms or federated learning are not available. To use these features, please upgrade to a recent Linux distro with glibc 2.28+, and install the 'manylinux_2_28' variant.
#   warnings.warn(
# **********************************
# Cargando fichero :datos/avocado.csv
# numero Registros :18249
# numero Columnas :14
# **********************************
#
#
# **********************************
# Cargando fichero :datos/avocado.csv
# numero Registros :18249
# numero Columnas :14
# **********************************

# %%
#P.P105_PRED.P100_1_Modelo_TRAINING_Mod('LinearRegression',ptrain_test_split ='SI')
P.P105_PRED.P100_1_Modelo_TRAINING_Mod(pNameModelo='LinearRegression',pFechaReal='2018-10-01')
P.P105_PRED.P105_3_PrediccionesMensuales('Media')
# Out:
# LinearRegression
# 2018-10-01
# 18249
# 18249
# X_train LEN: 14599
# MSE (Real): 0.150436
# RMSE (Real): 0.387861
# R² (Real): 0.072180
# MSE (Real): 0.150436
# RMSE (Real): 0.387861
# R² (Real): 0.072180
# Test Evaluación
# **************
# mse_train:0.1510853170281979
# rmse_train:0.3886969475416522
# r2_train:0.07024937166780854
# mse_test:0.147840748759251
# rmse_test:0.38450064858105376
# r2_test:0.07984320501212283
# **************
# Coeficientes del modelo LinearRegression:
# Característica: Cal_AAAA, Coeficiente: 0.051668623299403936
# Característica: Cal_SS, Coeficiente: 0.004042093648624689
# Característica: Total Volume, Coeficiente: -2.295262520330044e-08
#
#
# Fórmula de la regresión lineal:
# y = -102.8497 + -0.0000 * Total Volume + 0.0040 * Cal_SS + 0.0517 * Cal_AAAA
# Coeficientes (pesos):
# Total Volume: -0.0000
# Cal_SS: 0.0040
# Cal_AAAA: 0.0517
# Intercepto: -102.8497
# 5.3 | **Predicciones Mensuales Usando Datos Trimestrales:**
# ...

# %%
#P.P105_PRED.P100_1_Modelo_TRAINING_Mod('LinearRegression',ptrain_test_split ='SI')
P.P105_PRED.P100_1_Modelo_TRAINING_Mod('RandomForestRegressor',pFechaReal='2018-01-01')
P.P105_PRED.P105_3_PrediccionesMensuales('Media')
# Out:
# RandomForestRegressor
# 2018-01-01
# 18249
# 16953
# X_train LEN: 13562
# MSE (Real): 0.029004
# RMSE (Real): 0.170304
# R² (Real): 0.826438
# MSE (Real): 0.029004
# RMSE (Real): 0.170304
# R² (Real): 0.826438
# Test Evaluación
# **************
# mse_train:0.012737865976994542
# rmse_train:0.11286215475966486
# r2_train:0.9238174920725564
# mse_test:0.0940567662872309
# rmse_test:0.3066867559697205
# r2_test:0.43579154780904283
# **************
# Importancia de las características del modelo RandomForestRegressor:
# Característica: Total Volume, Importancia: 0.7193728383361031
# Característica: Cal_SS, Importancia: 0.20558753153406645
# Característica: Cal_AAAA, Importancia: 0.07503963012983043
# 5.3 | **Predicciones Mensuales Usando Datos Trimestrales:**
# - **Uso de Datos:** Agrupa datos por trimestres y segmenta en meses utilizando `Date`, `AveragePrice`, y `Total Volume`.
#    - **Esperado:**
#      - Convierte la columna `Date` a tipo datetime si es necesario.
# ...

# %%
P.app_fun.APP_DatosORG
